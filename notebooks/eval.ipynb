# %%
# !pip install tokenizers
# !pip install datasets
# !pip install git+https://github.com/huggingface/transformers
# !pip install wandb
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-rxgxq0zp
#   Running command git clone -q https://github.com/huggingface/transformers /tmp/pip-req-build-rxgxq0zp
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for transformers: filename=transformers-4.6.0.dev0-cp37-none-any.whl size=2123051 sha256=7b5b1b363756ecfb3aeac8780239d24387fecfe4d222d132946250c0b4639fbf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vdrdt5t0/wheels/70/d3/52/b3fa4f8b8ef04167ac62e5bb2accb62ae764db2a378247490e
# Successfully built transformers
# ...

# %%
cd drive/MyDrive/IFT6010/codexlm/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/IFT6010/codexlm/'
# /content/drive/MyDrive/IFT6010/codexlm

# %%
# !python eval_lm.py \
  --model_name_or_path ./model/codegpt-tuned-java-cs-flows/checkpoint-180/ \
  --eval_path ./data/completion-token/cs/test.java-cs.txt.cs.flow \
  --code_flows_path ./data/completion-token/java/test.java-cs.txt.java.flow
# Out:
# 2021-04-28 21:12:52.465471: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 04/28/2021 21:13:01 - WARNING - datasets.builder -   Using custom data configuration default-f2da86fdd4db7b1d
# 04/28/2021 21:13:01 - WARNING - datasets.builder -   Reusing dataset text (/root/.cache/huggingface/datasets/text/default-f2da86fdd4db7b1d/0.0.0/e16f44aa1b321ece1f87b07977cc5d70be93d69b20486d6dacd62e12cf25c9a5)
# 100% 1/1 [00:00<00:00,  5.66ba/s]
# 100% 1/1 [00:00<00:00,  7.12ba/s]
# 04/28/2021 21:13:01 - INFO - __main__ -   Evaluation set: DatasetDict({
#     test: Dataset({
#         features: ['input_ids', 'text'],
#         num_rows: 1000
#     })
#     flows: Dataset({
#         features: ['input_ids', 'text'],
#         num_rows: 1000
#     })
# })
# 100% 1000/1000 [09:33<00:00,  1.74it/s]
# {'[ARGS]': {'acc': 0.4732, 'n_test': 1156, 'ratio': 62.52},
#  '[CALL]': {'acc': 0.3465, 'n_test': 987, 'ratio': 54.62},
# ...
